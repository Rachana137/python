# %%
#hello this is my sample code
print("Hello Programmer")
# Out:
# Hello Programmer

# %%
#hello this is my sample code
print("Hello Programmer")
# Out:
# Hello Programmer

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
x=30

# %%
print(x)
# Out:
# 30

# %% [markdown]
# # Data Types

# %% [markdown]
# Data types are used to represent type of the data loaded in variables
